# %%
#pip install numpy
#pip install seaborn
#pip install panda
#pip install matplotlib
#pip install scikit-learn
#pip install plotly

# %%
# Importing the libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.decomposition import PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures, MinMaxScaler, LabelEncoder
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.ensemble import ExtraTreesRegressor
from __future__  import print_function #adds compatibility with new versions of Python
# %matplotlib inline 
#it needs to have two underscore for 'future', if not it thorws an error: 
#ModuleNotFoundError: No module named '_future_'

import warnings
warnings.filterwarnings("ignore") #This command ignores the warning

# %%
#Importing the dataset #1

#The dataset chosen for this project is listings for Airbnb 

listing = pd.read_csv('listings.csv')

# %%
#Importing the dataset #2

#The dataset chosen for this project is reviews for Airbnb 

review = pd.read_csv('reviews.csv')

# %%
#Importing the dataset # 3

#The dataset chosen for this project is calendar for Airbnb

calendar = pd.read_csv('calendar.csv')

# %%
#Importing the dataset # 4

#The dataset chosen for this project is the Dublin listings from OpenData 

airbnb_listing = pd.read_csv('airbnb-listings.csv', sep=";")

# %%
#Importing the dataset # 5

#The dataset chosen for this project is Dublin listings from OpenData 

airbnb_listing1 = pd.read_csv('airbnb-opendata.csv')

# %%
#Importing the dataset # 6

#The dataset chosen for this project is Dublin rate from Airbtics 
rate = pd.read_csv('rate.csv')

#this dataset is a sample, however it contains a lot of information. I needed to fix it as it didn't have the columns set right.

# %% [markdown]
# EDA to be done using and merging the first 5 datasets, needs to be cleaned, wrangled and adjsuted accordingly.

# %% [markdown]
# Some of the datasets are for trends and whether or not features influence reviews that influence occupancy that generates higher ROI.
# the dataset for ML is the last one, it is a sample data of Dublin, I want to identify the occupancy rate in the future.

# %%
rate.head()
# Out:
#   THIS IS A SAMPLE DATASET. PLEASE SUBSCRIBE TO YOUR MARKET TO GAIN FULL ACCESS TO ITS DATA!  \
# 0                                                NaN
# 1                                        Listing URL
# 2                      http://airbnb.com/rooms/47311
# 3                      http://airbnb.com/rooms/74819
# 4                      http://airbnb.com/rooms/76190
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4             Unnamed: 5  \
# 0            NaN        NaN        NaN          NaN                    NaN
# 1  Property Type   Latitude  Longitude  Star Rating  Number of Active Days
# 2    entire_home   50.81523   -0.10806          4.3                    274
# 3    Entire Home   50.82145   -0.14257          4.9                    243
# 4    entire_home   50.82369   -0.15587          4.5                    365
#
#   Unnamed: 6 Unnamed: 7    Unnamed: 8       Unnamed: 9  ...  \
# 0        NaN        NaN           NaN              NaN  ...
# 1   Bedrooms   Has pool  Cleaning Fee  Extra Guest Fee  ...
# 2          1          f            37                0  ...
# 3          3          f            52                0  ...
# 4          3          f            63          5.04667  ...
#
#          Unnamed: 36        Unnamed: 37        Unnamed: 38        Unnamed: 39  \
# 0                NaN                NaN                NaN                NaN
# 1  Revenue (2021-01)  Revenue (2021-02)  Revenue (2021-03)  Revenue (2021-04)
# 2                 62               1069               1588               2076
# 3               7078                  0                  0              15587
# 4               5920                833               2495               5881
#
#          Unnamed: 40        Unnamed: 41        Unnamed: 42        Unnamed: 43  \
# 0                NaN                NaN                NaN                NaN
# 1  Revenue (2021-05)  Revenue (2021-06)  Revenue (2021-07)  Revenue (2021-08)
# 2               2636               3237               3206                  0
# 3                  0                  0              15521              15622
# 4               7672               9570               9927              10492
#
#          Unnamed: 44        Unnamed: 45
# 0                NaN                NaN
# 1  Revenue (2021-09)  Revenue (2021-10)
# 2                  0                  0
# 3              13314              11036
# 4               6317               2113
#
# [5 rows x 46 columns]

# %%
#Based on the information on the dataset itself, I added these columns names. 
rate.columns = [
    "Listing URL",
    "Property Type",
    "Latitude",
    "Longitude",
    "Star Rating",
    "Number of Active Days",
    "Bedrooms",
    "Has pool",
    "Cleaning Fee",
    "Extra Guest Fee",
    "Daily Rate (2020-11)",
    "Daily Rate (2020-12)",
    "Daily Rate (2021-01)",
    "Daily Rate (2021-02)",
    "Daily Rate (2021-03)",
    "Daily Rate (2021-04)",
    "Daily Rate (2021-05)",
    "Daily Rate (2021-06)",
    "Daily Rate (2021-07)",
    "Daily Rate (2021-08)",
    "Daily Rate (2021-09)",
    "Daily Rate (2021-10)",
    "Occupancy Rate (2020-11)",
    "Occupancy Rate (2020-12)",
    "Occupancy Rate (2021-01)",
    "Occupancy Rate (2021-02)",
    "Occupancy Rate (2021-03)",
    "Occupancy Rate (2021-04)",
    "Occupancy Rate (2021-05)",
    "Occupancy Rate (2021-06)",
    "Occupancy Rate (2021-07)",
    "Occupancy Rate (2021-08)",
    "Occupancy Rate (2021-09)",
    "Occupancy Rate (2021-10)",
    "Revenue (2020-11)",
    "Revenue (2020-12)",
    "Revenue (2021-01)",
    "Revenue (2021-02)",
    "Revenue (2021-03)",
    "Revenue (2021-04)",
    "Revenue (2021-05)",
    "Revenue (2021-06)",
    "Revenue (2021-07)",
    "Revenue (2021-08)",
    "Revenue (2021-09)",
    "Revenue (2021-10)",
]

# %%
rate.head()
# Out:
#                      Listing URL  Property Type  Latitude  Longitude  \
# 0                            NaN            NaN       NaN        NaN
# 1                    Listing URL  Property Type  Latitude  Longitude
# 2  http://airbnb.com/rooms/47311    entire_home  50.81523   -0.10806
# 3  http://airbnb.com/rooms/74819    Entire Home  50.82145   -0.14257
# 4  http://airbnb.com/rooms/76190    entire_home  50.82369   -0.15587
#
#    Star Rating  Number of Active Days  Bedrooms  Has pool  Cleaning Fee  \
# 0          NaN                    NaN       NaN       NaN           NaN
# 1  Star Rating  Number of Active Days  Bedrooms  Has pool  Cleaning Fee
# 2          4.3                    274         1         f            37
# 3          4.9                    243         3         f            52
# 4          4.5                    365         3         f            63
#
#    Extra Guest Fee  ...  Revenue (2021-01)  Revenue (2021-02)  \
# 0              NaN  ...                NaN                NaN
# 1  Extra Guest Fee  ...  Revenue (2021-01)  Revenue (2021-02)
# 2                0  ...                 62               1069
# 3                0  ...               7078                  0
# 4          5.04667  ...               5920                833
#
#    Revenue (2021-03)  Revenue (2021-04)  Revenue (2021-05)  Revenue (2021-06)  \
# 0                NaN                NaN                NaN                NaN
# 1  Revenue (2021-03)  Revenue (2021-04)  Revenue (2021-05)  Revenue (2021-06)
# 2               1588               2076               2636               3237
# 3                  0              15587                  0                  0
# 4               2495               5881               7672               9570
#
#    Revenue (2021-07)  Revenue (2021-08)  Revenue (2021-09)  Revenue (2021-10)
# 0                NaN                NaN                NaN                NaN
# 1  Revenue (2021-07)  Revenue (2021-08)  Revenue (2021-09)  Revenue (2021-10)
# 2               3206                  0                  0                  0
# 3              15521              15622              13314              11036
# 4               9927              10492               6317               2113
#
# [5 rows x 46 columns]

# %%
#dropping the two first rows.
rate.drop(index=rate.index[0:2], 
        axis=0, 
        inplace=True)

# %%
rate.head()
# Out:
#                       Listing URL Property Type  Latitude Longitude  \
# 2   http://airbnb.com/rooms/47311   entire_home  50.81523  -0.10806
# 3   http://airbnb.com/rooms/74819   Entire Home  50.82145  -0.14257
# 4   http://airbnb.com/rooms/76190   entire_home  50.82369  -0.15587
# 5   http://airbnb.com/rooms/98654   entire_home  50.82094  -0.12963
# 6  http://airbnb.com/rooms/146850         condo  50.82178  -0.12914
#
#   Star Rating Number of Active Days Bedrooms Has pool Cleaning Fee  \
# 2         4.3                   274        1        f           37
# 3         4.9                   243        3        f           52
# 4         4.5                   365        3        f           63
# 5         4.5                   365        2        f           80
# 6         4.8                   274        1        f            0
#
#   Extra Guest Fee  ... Revenue (2021-01) Revenue (2021-02) Revenue (2021-03)  \
# 2               0  ...                62              1069              1588
# 3               0  ...              7078                 0                 0
# 4         5.04667  ...              5920               833              2495
# 5         4.94667  ...              2283              2283              2283
# 6               0  ...               819                 0                 0
#
#   Revenue (2021-04) Revenue (2021-05) Revenue (2021-06) Revenue (2021-07)  \
# 2              2076              2636              3237              3206
# 3             15587                 0                 0             15521
# 4              5881              7672              9570              9927
# 5              2283              2283              2283              2283
# 6              1067               960                 0              1067
#
#   Revenue (2021-08) Revenue (2021-09) Revenue (2021-10)
# 2                 0                 0                 0
# 3             15622             13314             11036
# 4             10492              6317              2113
# 5              2283              2283              2283
# 6              1046               974              1005
#
# [5 rows x 46 columns]

# %%
rate.isnull().sum()
# Out:
# Listing URL                  0
# Property Type                0
# Latitude                     0
# Longitude                    0
# Star Rating                  0
# Number of Active Days        0
# Bedrooms                     0
# Has pool                     0
# Cleaning Fee                23
# Extra Guest Fee             23
# Daily Rate (2020-11)         0
# Daily Rate (2020-12)         0
# Daily Rate (2021-01)         0
# Daily Rate (2021-02)         0
# Daily Rate (2021-03)         0
# Daily Rate (2021-04)         0
# Daily Rate (2021-05)         0
# Daily Rate (2021-06)         0
# Daily Rate (2021-07)         0
# Daily Rate (2021-08)         0
# Daily Rate (2021-09)         0
# Daily Rate (2021-10)         0
# Occupancy Rate (2020-11)     0
# Occupancy Rate (2020-12)     0
# Occupancy Rate (2021-01)     0
# Occupancy Rate (2021-02)     0
# Occupancy Rate (2021-03)     0
# Occupancy Rate (2021-04)     0
# Occupancy Rate (2021-05)     0
# Occupancy Rate (2021-06)     0
# Occupancy Rate (2021-07)     0
# Occupancy Rate (2021-08)     0
# Occupancy Rate (2021-09)     0
# Occupancy Rate (2021-10)     0
# Revenue (2020-11)            0
# Revenue (2020-12)            0
# Revenue (2021-01)            0
# Revenue (2021-02)            0
# Revenue (2021-03)            0
# Revenue (2021-04)            0
# Revenue (2021-05)            0
# Revenue (2021-06)            0
# Revenue (2021-07)            0
# Revenue (2021-08)            0
# Revenue (2021-09)            0
# Revenue (2021-10)            0
# dtype: int64

# %%
#replacing all NaN values with 0
rate.fillna({'Cleaning Fee':0}, inplace=True)
rate.fillna({'Extra Guest Fee':0}, inplace=True)

# %%
rate.isnull().sum()
# Out:
# Listing URL                 0
# Property Type               0
# Latitude                    0
# Longitude                   0
# Star Rating                 0
# Number of Active Days       0
# Bedrooms                    0
# Has pool                    0
# Cleaning Fee                0
# Extra Guest Fee             0
# Daily Rate (2020-11)        0
# Daily Rate (2020-12)        0
# Daily Rate (2021-01)        0
# Daily Rate (2021-02)        0
# Daily Rate (2021-03)        0
# Daily Rate (2021-04)        0
# Daily Rate (2021-05)        0
# Daily Rate (2021-06)        0
# Daily Rate (2021-07)        0
# Daily Rate (2021-08)        0
# Daily Rate (2021-09)        0
# Daily Rate (2021-10)        0
# Occupancy Rate (2020-11)    0
# Occupancy Rate (2020-12)    0
# Occupancy Rate (2021-01)    0
# Occupancy Rate (2021-02)    0
# Occupancy Rate (2021-03)    0
# Occupancy Rate (2021-04)    0
# Occupancy Rate (2021-05)    0
# Occupancy Rate (2021-06)    0
# Occupancy Rate (2021-07)    0
# Occupancy Rate (2021-08)    0
# Occupancy Rate (2021-09)    0
# Occupancy Rate (2021-10)    0
# Revenue (2020-11)           0
# Revenue (2020-12)           0
# Revenue (2021-01)           0
# Revenue (2021-02)           0
# Revenue (2021-03)           0
# Revenue (2021-04)           0
# Revenue (2021-05)           0
# Revenue (2021-06)           0
# Revenue (2021-07)           0
# Revenue (2021-08)           0
# Revenue (2021-09)           0
# Revenue (2021-10)           0
# dtype: int64

# %%
#examine the dataset
(rate[['Star Rating', 'Number of Active Days', 'Daily Rate (2020-12)', 'Occupancy Rate (2020-12)',
       'Revenue (2020-12)']]
 .describe())
# Out:
#        Star Rating Number of Active Days Daily Rate (2020-12)  \
# count         3026                  3026                 3026
# unique          26                    13                  512
# top              5                   365                   -1
# freq           853                  2126                  371
#
#        Occupancy Rate (2020-12) Revenue (2020-12)
# count                      3026              3026
# unique                      102              1468
# top                          -1                -1
# freq                        600               603

# %%
#need to be encoded to integer

rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3026 entries, 2 to 3027
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Listing URL               3026 non-null   object
#  1   Property Type             3026 non-null   object
#  2   Latitude                  3026 non-null   object
#  3   Longitude                 3026 non-null   object
#  4   Star Rating               3026 non-null   object
#  5   Number of Active Days     3026 non-null   object
#  6   Bedrooms                  3026 non-null   object
#  7   Has pool                  3026 non-null   object
#  8   Cleaning Fee              3026 non-null   object
#  9   Extra Guest Fee           3026 non-null   object
#  10  Daily Rate (2020-11)      3026 non-null   object
#  11  Daily Rate (2020-12)      3026 non-null   object
#  12  Daily Rate (2021-01)      3026 non-null   object
#  13  Daily Rate (2021-02)      3026 non-null   object
#  14  Daily Rate (2021-03)      3026 non-null   object
#  15  Daily Rate (2021-04)      3026 non-null   object
#  16  Daily Rate (2021-05)      3026 non-null   object
#  17  Daily Rate (2021-06)      3026 non-null   object
#  18  Daily Rate (2021-07)      3026 non-null   object
#  19  Daily Rate (2021-08)      3026 non-null   object
#  20  Daily Rate (2021-09)      3026 non-null   object
#  21  Daily Rate (2021-10)      3026 non-null   object
#  22  Occupancy Rate (2020-11)  3026 non-null   object
#  23  Occupancy Rate (2020-12)  3026 non-null   object
#  24  Occupancy Rate (2021-01)  3026 non-null   object
#  25  Occupancy Rate (2021-02)  3026 non-null   object
#  26  Occupancy Rate (2021-03)  3026 non-null   object
#  27  Occupancy Rate (2021-04)  3026 non-null   object
#  28  Occupancy Rate (2021-05)  3026 non-null   object
#  29  Occupancy Rate (2021-06)  3026 non-null   object
#  30  Occupancy Rate (2021-07)  3026 non-null   object
#  31  Occupancy Rate (2021-08)  3026 non-null   object
#  32  Occupancy Rate (2021-09)  3026 non-null   object
#  33  Occupancy Rate (2021-10)  3026 non-null   object
#  34  Revenue (2020-11)         3026 non-null   object
#  35  Revenue (2020-12)         3026 non-null   object
#  36  Revenue (2021-01)         3026 non-null   object
#  37  Revenue (2021-02)         3026 non-null   object
#  38  Revenue (2021-03)         3026 non-null   object
#  39  Revenue (2021-04)         3026 non-null   object
#  40  Revenue (2021-05)         3026 non-null   object
#  41  Revenue (2021-06)         3026 non-null   object
#  42  Revenue (2021-07)         3026 non-null   object
#  43  Revenue (2021-08)         3026 non-null   object
#  44  Revenue (2021-09)         3026 non-null   object
#  45  Revenue (2021-10)         3026 non-null   object
# dtypes: object(46)
# memory usage: 1.1+ MB

# %%
#separating the dataset into categorical and numeric

#later to change the object type to float64

categorical_col = ['Listing URL','Property Type', 'Has pool']

numeric_col = ['Latitude', 
               'Longitude', 
               'Star Rating', 
               'Number of Active Days', 
               'Bedrooms', 
               'Cleaning Fee', 
               'Extra Guest Fee',            
               'Daily Rate (2020-11)',         
               'Daily Rate (2020-12)',
               'Daily Rate (2021-01)',
               'Daily Rate (2021-02)',        
               'Daily Rate (2021-03)',       
                'Daily Rate (2021-04)',        
                'Daily Rate (2021-05)',        
                'Daily Rate (2021-06)',        
                'Daily Rate (2021-07)',        
                'Daily Rate (2021-08)',        
                'Daily Rate (2021-09)',        
                'Daily Rate (2021-10)',        
                'Occupancy Rate (2020-11)',    
                'Occupancy Rate (2020-12)',   
                'Occupancy Rate (2021-01)',    
                'Occupancy Rate (2021-02)',    
                'Occupancy Rate (2021-03)',    
                'Occupancy Rate (2021-04)',    
                'Occupancy Rate (2021-05)',    
                'Occupancy Rate (2021-06)',    
                'Occupancy Rate (2021-07)',    
                'Occupancy Rate (2021-08)',    
                'Occupancy Rate (2021-09)',    
                'Occupancy Rate (2021-10)',   
                'Revenue (2020-11)',           
                'Revenue (2020-12)',         
                'Revenue (2021-01)',           
                'Revenue (2021-02)',           
                'Revenue (2021-03)',           
                'Revenue (2021-04)',           
                'Revenue (2021-05)',           
                'Revenue (2021-06)',           
                'Revenue (2021-07)',           
                'Revenue (2021-08)',           
                'Revenue (2021-09)',           
                'Revenue (2021-10)',
              ]

# %%
print(numeric_col)
# Out:
# ['Latitude', 'Longitude', 'Star Rating', 'Number of Active Days', 'Bedrooms', 'Cleaning Fee', 'Extra Guest Fee', 'Daily Rate (2020-11)', 'Daily Rate (2020-12)', 'Daily Rate (2021-01)', 'Daily Rate (2021-02)', 'Daily Rate (2021-03)', 'Daily Rate (2021-04)', 'Daily Rate (2021-05)', 'Daily Rate (2021-06)', 'Daily Rate (2021-07)', 'Daily Rate (2021-08)', 'Daily Rate (2021-09)', 'Daily Rate (2021-10)', 'Occupancy Rate (2020-11)', 'Occupancy Rate (2020-12)', 'Occupancy Rate (2021-01)', 'Occupancy Rate (2021-02)', 'Occupancy Rate (2021-03)', 'Occupancy Rate (2021-04)', 'Occupancy Rate (2021-05)', 'Occupancy Rate (2021-06)', 'Occupancy Rate (2021-07)', 'Occupancy Rate (2021-08)', 'Occupancy Rate (2021-09)', 'Occupancy Rate (2021-10)', 'Revenue (2020-11)', 'Revenue (2020-12)', 'Revenue (2021-01)', 'Revenue (2021-02)', 'Revenue (2021-03)', 'Revenue (2021-04)', 'Revenue (2021-05)', 'Revenue (2021-06)', 'Revenue (2021-07)', 'Revenue (2021-08)', 'Revenue (2021-09)', 'Revenue (2021-10)']

# %%
rate[numeric_col] = rate[numeric_col].apply(pd.to_numeric, errors='coerce')

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3026 entries, 2 to 3027
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Listing URL               3026 non-null   object
#  1   Property Type             3026 non-null   object
#  2   Latitude                  3026 non-null   float64
#  3   Longitude                 3026 non-null   float64
#  4   Star Rating               3026 non-null   float64
#  5   Number of Active Days     3026 non-null   int64
#  6   Bedrooms                  2868 non-null   float64
#  7   Has pool                  3026 non-null   object
#  8   Cleaning Fee              3026 non-null   int64
#  9   Extra Guest Fee           3026 non-null   float64
#  10  Daily Rate (2020-11)      3026 non-null   int64
#  11  Daily Rate (2020-12)      3026 non-null   int64
#  12  Daily Rate (2021-01)      3026 non-null   int64
#  13  Daily Rate (2021-02)      3026 non-null   int64
#  14  Daily Rate (2021-03)      3026 non-null   int64
#  15  Daily Rate (2021-04)      3026 non-null   int64
#  16  Daily Rate (2021-05)      3026 non-null   int64
#  17  Daily Rate (2021-06)      3026 non-null   int64
#  18  Daily Rate (2021-07)      3026 non-null   int64
#  19  Daily Rate (2021-08)      3026 non-null   int64
#  20  Daily Rate (2021-09)      3026 non-null   int64
#  21  Daily Rate (2021-10)      3026 non-null   int64
#  22  Occupancy Rate (2020-11)  3026 non-null   int64
#  23  Occupancy Rate (2020-12)  3026 non-null   int64
#  24  Occupancy Rate (2021-01)  3026 non-null   int64
#  25  Occupancy Rate (2021-02)  3026 non-null   int64
#  26  Occupancy Rate (2021-03)  3026 non-null   int64
#  27  Occupancy Rate (2021-04)  3026 non-null   int64
#  28  Occupancy Rate (2021-05)  3026 non-null   int64
#  29  Occupancy Rate (2021-06)  3026 non-null   int64
#  30  Occupancy Rate (2021-07)  3026 non-null   int64
#  31  Occupancy Rate (2021-08)  3026 non-null   int64
#  32  Occupancy Rate (2021-09)  3026 non-null   int64
#  33  Occupancy Rate (2021-10)  3026 non-null   int64
#  34  Revenue (2020-11)         3026 non-null   int64
#  35  Revenue (2020-12)         3026 non-null   int64
#  36  Revenue (2021-01)         3026 non-null   int64
#  37  Revenue (2021-02)         3026 non-null   int64
#  38  Revenue (2021-03)         3026 non-null   int64
#  39  Revenue (2021-04)         3026 non-null   int64
#  40  Revenue (2021-05)         3026 non-null   int64
#  41  Revenue (2021-06)         3026 non-null   int64
#  42  Revenue (2021-07)         3026 non-null   int64
#  43  Revenue (2021-08)         3026 non-null   int64
#  44  Revenue (2021-09)         3026 non-null   int64
#  45  Revenue (2021-10)         3026 non-null   int64
# dtypes: float64(5), int64(38), object(3)
# memory usage: 1.1+ MB

# %%
#NOT NEEDED - things I tried.
#encoding the dataset so that I can add columns for the rates values. 
#rate['Cleaning Fee'] = rate['Cleaning Fee'].astype(float)

# %%
rate.drop(columns=['Listing URL', 'Property Type', 'Latitude', 'Longitude', 'Has pool'])
# Out:
#       Star Rating  Number of Active Days  Bedrooms  Cleaning Fee  \
# 2             4.3                    274       1.0            37
# 3             4.9                    243       3.0            52
# 4             4.5                    365       3.0            63
# 5             4.5                    365       2.0            80
# 6             4.8                    274       1.0             0
# ...           ...                    ...       ...           ...
# 3023          0.0                    365       2.0            69
# 3024          0.0                    365       1.0            80
# 3025          5.0                    365       1.0            55
# 3026          0.0                    365       1.0            80
# 3027          0.0                    365       1.0             0
#
#       Extra Guest Fee  Daily Rate (2020-11)  Daily Rate (2020-12)  \
# 2             0.00000                    88                    88
# 3             0.00000                   283                   270
# 4             5.04667                   201                   249
# 5             4.94667                   182                   221
# 6             0.00000                    33                    33
# ...               ...                   ...                   ...
# 3023          5.52667                   180                   180
# 3024          0.00000                    82                    82
# 3025          0.00000                    39                    39
# 3026          0.00000                    59                    59
# 3027          0.00000                    69                    69
#
#       Daily Rate (2021-01)  Daily Rate (2021-02)  Daily Rate (2021-03)  ...  \
# 2                       90                    91                    92  ...
# 3                      238                   280                   404  ...
# 4                      222                   207                   143  ...
# 5                      194                   194                   194  ...
# 6                       34                    34                    35  ...
# ...                    ...                   ...                   ...  ...
# 3023                   180                   180                   180  ...
# 3024                    82                    82                    82  ...
# 3025                    39                    39                    39  ...
# 3026                    59                    59                    59  ...
# 3027                    69                    69                    69  ...
#
#       Revenue (2021-01)  Revenue (2021-02)  Revenue (2021-03)  \
# 2                    62               1069               1588
# 3                  7078                  0                  0
# 4                  5920                833               2495
# 5                  2283               2283               2283
# 6                   819                  0                  0
# ...                 ...                ...                ...
# 3023                123                123                123
# 3024               1716               1716               1716
# 3025               1235               1235               1235
# 3026               1273               1273               1273
# 3027               1388               1388               1388
#
#       Revenue (2021-04)  Revenue (2021-05)  Revenue (2021-06)  \
# 2                  2076               2636               3237
# 3                 15587                  0                  0
# 4                  5881               7672               9570
# 5                  2283               2283               2283
# 6                  1067                960                  0
# ...                 ...                ...                ...
# 3023               1991               4053               6782
# 3024               2845               4519               5453
# 3025               1235               1235               1235
# 3026               2448               4594               5642
# 3027               1851               3201               3843
#
#       Revenue (2021-07)  Revenue (2021-08)  Revenue (2021-09)  \
# 2                  3206                  0                  0
# 3                 15521              15622              13314
# 4                  9927              10492               6317
# 5                  2283               2283               2283
# 6                  1067               1046                974
# ...                 ...                ...                ...
# 3023               7778               7882               3650
# 3024               6471               5192               3434
# 3025               1235               1235               1235
# 3026               6663               6016               6181
# 3027               4481               4093               2596
#
#       Revenue (2021-10)
# 2                     0
# 3                 11036
# 4                  2113
# 5                  2283
# 6                  1005
# ...                 ...
# 3023               2927
# 3024               2907
# 3025               1235
# 3026               2848
# 3027               3085
#
# [3026 rows x 41 columns]

# %%
#mean all the Revenue, Occupancy and Daily Rate

rate['daily_rate_mean'] = rate[['Daily Rate (2021-01)','Daily Rate (2021-02)', 'Daily Rate (2021-03)','Daily Rate (2021-04)', 'Daily Rate (2021-05)','Daily Rate (2021-06)', 'Daily Rate (2021-07)','Daily Rate (2021-08)', 'Daily Rate (2021-09)','Daily Rate (2021-10)', 'Daily Rate (2020-11)','Daily Rate (2020-12)']].mean(axis=1)

rate['revenue_mean'] = rate[['Revenue (2020-11)','Revenue (2020-12)','Revenue (2021-01)','Revenue (2021-02)','Revenue (2021-03)','Revenue (2021-04)',          'Revenue (2021-05)','Revenue (2021-06)','Revenue (2021-07)','Revenue (2021-08)','Revenue (2021-09)','Revenue (2021-10)']].mean(axis=1)

rate['occupancy_mean'] = rate[['Occupancy Rate (2020-11)','Occupancy Rate (2020-12)','Occupancy Rate (2021-01)','Occupancy Rate (2021-02)','Occupancy Rate (2021-03)','Occupancy Rate (2021-04)','Occupancy Rate (2021-05)','Occupancy Rate (2021-06)','Occupancy Rate (2021-07)','Occupancy Rate (2021-08)','Occupancy Rate (2021-09)','Occupancy Rate (2021-10)']].mean(axis=1)

# %%
rate.head()
# Out:
#                       Listing URL Property Type  Latitude  Longitude  \
# 2   http://airbnb.com/rooms/47311   entire_home  50.81523   -0.10806
# 3   http://airbnb.com/rooms/74819   Entire Home  50.82145   -0.14257
# 4   http://airbnb.com/rooms/76190   entire_home  50.82369   -0.15587
# 5   http://airbnb.com/rooms/98654   entire_home  50.82094   -0.12963
# 6  http://airbnb.com/rooms/146850         condo  50.82178   -0.12914
#
#    Star Rating  Number of Active Days  Bedrooms Has pool  Cleaning Fee  \
# 2          4.3                    274       1.0        f            37
# 3          4.9                    243       3.0        f            52
# 4          4.5                    365       3.0        f            63
# 5          4.5                    365       2.0        f            80
# 6          4.8                    274       1.0        f             0
#
#    Extra Guest Fee  ...  Revenue (2021-04)  Revenue (2021-05)  \
# 2          0.00000  ...               2076               2636
# 3          0.00000  ...              15587                  0
# 4          5.04667  ...               5881               7672
# 5          4.94667  ...               2283               2283
# 6          0.00000  ...               1067                960
#
#    Revenue (2021-06)  Revenue (2021-07)  Revenue (2021-08)  Revenue (2021-09)  \
# 2               3237               3206                  0                  0
# 3                  0              15521              15622              13314
# 4               9570               9927              10492               6317
# 5               2283               2283               2283               2283
# 6                  0               1067               1046                974
#
#    Revenue (2021-10)  daily_rate_mean  revenue_mean  occupancy_mean
# 2                  0        90.833333   1166.333333       36.583333
# 3              11036       399.916667   7871.000000       63.000000
# 4               2113       251.833333   6100.583333       70.666667
# 5               2283       195.250000   2296.000000       34.000000
# 6               1005        34.333333    710.666667       68.000000
#
# [5 rows x 49 columns]

# %%
rate = rate.drop(['Daily Rate (2021-01)','Daily Rate (2021-02)', 'Daily Rate (2021-03)','Daily Rate (2021-04)', 'Daily Rate (2021-05)','Daily Rate (2021-06)', 'Daily Rate (2021-07)','Daily Rate (2021-08)', 'Daily Rate (2021-09)','Daily Rate (2021-10)', 'Daily Rate (2020-11)','Daily Rate (2020-12)','Revenue (2020-11)','Revenue (2020-12)','Revenue (2021-01)','Revenue (2021-02)','Revenue (2021-03)','Revenue (2021-04)','Revenue (2021-05)','Revenue (2021-06)','Revenue (2021-07)','Revenue (2021-08)','Revenue (2021-09)','Revenue (2021-10)','Occupancy Rate (2020-11)','Occupancy Rate (2020-12)','Occupancy Rate (2021-01)','Occupancy Rate (2021-02)','Occupancy Rate (2021-03)','Occupancy Rate (2021-04)','Occupancy Rate (2021-05)','Occupancy Rate (2021-06)','Occupancy Rate (2021-07)','Occupancy Rate (2021-08)','Occupancy Rate (2021-09)','Occupancy Rate (2021-10)'], axis=1)

# %%
#del rate['Daily Rate (2021-01)','Daily Rate (2021-02)', 'Daily Rate (2021-03)','Daily Rate (2021-04)', 'Daily Rate (2021-05)','Daily Rate (2021-06)', 'Daily Rate (2021-07)','Daily Rate (2021-08)', 'Daily Rate (2021-09)','Daily Rate (2021-10)', 'Daily Rate (2020-11)','Daily Rate (2020-12)','Revenue (2020-11)','Revenue (2020-12)','Revenue (2021-01)','Revenue (2021-02)','Revenue (2021-03)','Revenue (2021-04)',          'Revenue (2021-05)','Revenue (2021-06)','Revenue (2021-07)','Revenue (2021-08)','Revenue (2021-09)','Revenue (2021-10)','Occupancy Rate (2020-11)','Occupancy Rate (2020-12)','Occupancy Rate (2021-01)','Occupancy Rate (2021-02)','Occupancy Rate (2021-03)','Occupancy Rate (2021-04)','Occupancy Rate (2021-05)','Occupancy Rate (2021-06)','Occupancy Rate (2021-07)','Occupancy Rate (2021-08)','Occupancy Rate (2021-09)','Occupancy Rate (2021-10)']

# %%
rate.head()
# Out:
#                       Listing URL Property Type  Latitude  Longitude  \
# 2   http://airbnb.com/rooms/47311   entire_home  50.81523   -0.10806
# 3   http://airbnb.com/rooms/74819   Entire Home  50.82145   -0.14257
# 4   http://airbnb.com/rooms/76190   entire_home  50.82369   -0.15587
# 5   http://airbnb.com/rooms/98654   entire_home  50.82094   -0.12963
# 6  http://airbnb.com/rooms/146850         condo  50.82178   -0.12914
#
#    Star Rating  Number of Active Days  Bedrooms Has pool  Cleaning Fee  \
# 2          4.3                    274       1.0        f            37
# 3          4.9                    243       3.0        f            52
# 4          4.5                    365       3.0        f            63
# 5          4.5                    365       2.0        f            80
# 6          4.8                    274       1.0        f             0
#
#    Extra Guest Fee  daily_rate_mean  revenue_mean  occupancy_mean
# 2          0.00000        90.833333   1166.333333       36.583333
# 3          0.00000       399.916667   7871.000000       63.000000
# 4          5.04667       251.833333   6100.583333       70.666667
# 5          4.94667       195.250000   2296.000000       34.000000
# 6          0.00000        34.333333    710.666667       68.000000

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3026 entries, 2 to 3027
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Listing URL            3026 non-null   object
#  1   Property Type          3026 non-null   object
#  2   Latitude               3026 non-null   float64
#  3   Longitude              3026 non-null   float64
#  4   Star Rating            3026 non-null   float64
#  5   Number of Active Days  3026 non-null   int64
#  6   Bedrooms               2868 non-null   float64
#  7   Has pool               3026 non-null   object
#  8   Cleaning Fee           3026 non-null   int64
#  9   Extra Guest Fee        3026 non-null   float64
#  10  daily_rate_mean        3026 non-null   float64
#  11  revenue_mean           3026 non-null   float64
#  12  occupancy_mean         3026 non-null   float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 331.0+ KB

# %%
#correlations - example 

rate.corr() # Whole correlation matrix
rate.corr()['revenue_mean'] # Check correlations with outcome only
sns.heatmap(rate.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
#correlations - example 

rate.corr() # Whole correlation matrix
rate.corr()['daily_rate_mean'] # Check correlations with outcome only
sns.heatmap(rate.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
#correlations - example 

rate.corr() # Whole correlation matrix
rate.corr()['occupancy_mean'] # Check correlations with outcome only
sns.heatmap(rate.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
# Import packages
import pandas as pd
import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import lars_path
from sklearn.linear_model import LinearRegression, Lasso, LassoCV
from sklearn.metrics import r2_score
import scipy.stats as stats
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.distplot(rate['daily_rate_mean'], kde=True,);
fig = plt.figure()
res = stats.probplot(rate['daily_rate_mean'], plot=plt)
print("Skewness: %f" % rate['daily_rate_mean'].skew())
print("Kurtosis: %f" % rate['daily_rate_mean'].kurt())

#Need to review this as the dataset looks skewed
# Out:
# Skewness: 4.078485
# Kurtosis: 26.157308

# %%
rate.head()
# Out:
#                       Listing URL Property Type  Latitude  Longitude  \
# 2   http://airbnb.com/rooms/47311   entire_home  50.81523   -0.10806
# 3   http://airbnb.com/rooms/74819   Entire Home  50.82145   -0.14257
# 4   http://airbnb.com/rooms/76190   entire_home  50.82369   -0.15587
# 5   http://airbnb.com/rooms/98654   entire_home  50.82094   -0.12963
# 6  http://airbnb.com/rooms/146850         condo  50.82178   -0.12914
#
#    Star Rating  Number of Active Days  Bedrooms Has pool  Cleaning Fee  \
# 2          4.3                    274       1.0        f            37
# 3          4.9                    243       3.0        f            52
# 4          4.5                    365       3.0        f            63
# 5          4.5                    365       2.0        f            80
# 6          4.8                    274       1.0        f             0
#
#    Extra Guest Fee  daily_rate_mean  revenue_mean  occupancy_mean
# 2          0.00000        90.833333   1166.333333       36.583333
# 3          0.00000       399.916667   7871.000000       63.000000
# 4          5.04667       251.833333   6100.583333       70.666667
# 5          4.94667       195.250000   2296.000000       34.000000
# 6          0.00000        34.333333    710.666667       68.000000

# %%
review.head()
# Out:
#    listing_id      id        date  reviewer_id         reviewer_name  \
# 0       44077  203703  2011-03-20       393348             Christian
# 1       44077  211369  2011-03-28       444004               Solidea
# 2       44077  234215  2011-04-21       465058  Michael And Isabelle
# 3       44077  261843  2011-05-13       490005                Weston
# 4       44077  268148  2011-05-17       520460               Barbara
#
#                                             comments
# 0  We enjoyed our stay very much. The room was co...
# 1  We have been here 4 nights. Stay in a home is ...
# 2  Teresa and Hughie were great hosts. They were ...
# 3  No surprises, was as described.  Very gracious...
# 4  Teresa was a lovely hostess, and we had a deli...

# %% [markdown]
# # Listing dataset

# %%
listing.head()
# Out:
#        id                                          name  host_id host_name  \
# 0   44077           cosy comfortable Irish cottage twin   193005    Teresa
# 1   85148              Habitación en Dublín Double room   466111       Don
# 2   85156  Cosy Comfortable Irish Cottage  1 Double Bed   193005    Teresa
# 3  159889                          Friendly Single Room   766611  Margaret
# 4  162809            5.5 miles south of Dublin City :^)   777681    Robert
#
#    neighbourhood_group          neighbourhood  latitude  longitude  \
# 0                  NaN  Dn Laoghaire-Rathdown  53.29178   -6.25792
# 1                  NaN           South Dublin  53.29885   -6.31850
# 2                  NaN  Dn Laoghaire-Rathdown  53.29209   -6.25624
# 3                  NaN            Dublin City  53.39027   -6.23547
# 4                  NaN  Dn Laoghaire-Rathdown  53.28326   -6.19188
#
#       room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Private room     65               3                227   6 03 2020
# 1  Private room     30               1                  1  11 05 2019
# 2  Private room     61               3                182   9 03 2020
# 3  Private room     40               2                316   5 12 2021
# 4  Private room     65               1                288  19 10 2021
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.74                               3               233
# 1               0.03                               1                99
# 2               1.42                               3               323
# 3               2.67                               3               324
# 4               3.62                               2               114
#
#    number_of_reviews_ltm  license
# 0                      0      NaN
# 1                      0      NaN
# 2                      0      NaN
# 3                      5      NaN
# 4                      4      NaN

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6977 entries, 0 to 6976
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              6977 non-null   int64
#  1   name                            6976 non-null   object
#  2   host_id                         6977 non-null   int64
#  3   host_name                       6968 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   6977 non-null   object
#  6   latitude                        6977 non-null   float64
#  7   longitude                       6977 non-null   float64
#  8   room_type                       6977 non-null   object
#  9   price                           6977 non-null   int64
#  10  minimum_nights                  6977 non-null   int64
#  11  number_of_reviews               6977 non-null   int64
#  12  last_review                     5527 non-null   object
#  13  reviews_per_month               5527 non-null   float64
#  14  calculated_host_listings_count  6977 non-null   int64
#  15  availability_365                6977 non-null   int64
#  16  number_of_reviews_ltm           6977 non-null   int64
#  17  license                         0 non-null      float64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 981.3+ KB

# %%
# Drop the data that are not of interest and/or causing privacy issues
listing.drop(['id','host_name','last_review'], axis=1, inplace=True)
# Visualize the first 5 rows
listing.head(100)
# Out:
#                                                 name   host_id  \
# 0                cosy comfortable Irish cottage twin    193005
# 1                   Habitación en Dublín Double room    466111
# 2       Cosy Comfortable Irish Cottage  1 Double Bed    193005
# 3                               Friendly Single Room    766611
# 4                 5.5 miles south of Dublin City :^)    777681
# ..                                               ...       ...
# 95  Boutique Chic 2, 10min Temple Bar! Fab location.    192210
# 96                   2 single cosy rooms in Ranelagh   6782586
# 97                   City Centre Apartment, sleeps 2  10583714
# 98               Ensuite luxury - Dublin city center   5670240
# 99                    Great Penthouse In City Centre   4681988
#
#     neighbourhood_group          neighbourhood  latitude  longitude  \
# 0                   NaN  Dn Laoghaire-Rathdown  53.29178   -6.25792
# 1                   NaN           South Dublin  53.29885   -6.31850
# 2                   NaN  Dn Laoghaire-Rathdown  53.29209   -6.25624
# 3                   NaN            Dublin City  53.39027   -6.23547
# 4                   NaN  Dn Laoghaire-Rathdown  53.28326   -6.19188
# ..                  ...                    ...       ...        ...
# 95                  NaN            Dublin City  53.36581   -6.32408
# 96                  NaN            Dublin City  53.32338   -6.25333
# 97                  NaN            Dublin City  53.34665   -6.26371
# 98                  NaN            Dublin City  53.34932   -6.26709
# 99                  NaN            Dublin City  53.33914   -6.26709
#
#           room_type  price  minimum_nights  number_of_reviews  \
# 0      Private room     65               3                227
# 1      Private room     30               1                  1
# 2      Private room     61               3                182
# 3      Private room     40               2                316
# 4      Private room     65               1                288
# ..              ...    ...             ...                ...
# 95  Entire home/apt    600              14                188
# 96     Private room     50               3                269
# 97  Entire home/apt     95              14                 64
# 98     Private room     80               2                 48
# 99  Entire home/apt     70               2                  7
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                1.74                               3               233
# 1                0.03                               1                99
# 2                1.42                               3               323
# 3                2.67                               3               324
# 4                3.62                               2               114
# ..                ...                             ...               ...
# 95               1.94                               3                53
# 96               2.83                               2               240
# 97               0.91                               1                 0
# 98               0.58                               1                 9
# 99               0.12                               1                 0
#
#     number_of_reviews_ltm  license
# 0                       0      NaN
# 1                       0      NaN
# 2                       0      NaN
# 3                       5      NaN
# 4                       4      NaN
# ..                    ...      ...
# 95                      0      NaN
# 96                     11      NaN
# 97                      0      NaN
# 98                      0      NaN
# 99                      0      NaN
#
# [100 rows x 15 columns]

# %%
listing.isnull().sum()
# Out:
# name                                 1
# host_id                              0
# neighbourhood_group               6977
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 1450
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           6977
# dtype: int64

# %%
listing.fillna({'reviews_per_month':0}, inplace=True)

# %%
(listing[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
       'calculated_host_listings_count', 'availability_365']]
 .describe())
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  6.977000e+03     6977.000000        6977.000000        6977.000000
# mean   3.019986e+02        8.927189          30.272753           0.762961
# std    1.405164e+04       42.118071          59.819724           1.883356
# min    9.000000e+00        1.000000           0.000000           0.000000
# 25%    5.500000e+01        1.000000           1.000000           0.020000
# 50%    8.500000e+01        2.000000           6.000000           0.210000
# 75%    1.480000e+02        4.000000          29.000000           0.900000
# max    1.173721e+06     1125.000000         648.000000          81.060000
#
#        calculated_host_listings_count  availability_365
# count                     6977.000000       6977.000000
# mean                         7.251971         65.408772
# std                         25.062374        114.209065
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000          0.000000
# 75%                          3.000000         78.000000
# max                        162.000000        365.000000

# %%
listing = listing.loc[listing['price'] > 0]

# %%
listing.describe()
# Out:
#             host_id  neighbourhood_group     latitude    longitude  \
# count  6.977000e+03                  0.0  6977.000000  6977.000000
# mean   1.023079e+08                  NaN    53.345333    -6.255625
# std    1.005189e+08                  NaN     0.044036     0.057919
# min    4.398400e+04                  NaN    53.205780    -6.488790
# 25%    2.441876e+07                  NaN    53.330220    -6.278780
# 50%    6.504127e+07                  NaN    53.343990    -6.260634
# 75%    1.534091e+08                  NaN    53.356460    -6.235200
# max    4.349262e+08                  NaN    53.623490    -6.052910
#
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  6.977000e+03     6977.000000        6977.000000        6977.000000
# mean   3.019986e+02        8.927189          30.272753           0.762961
# std    1.405164e+04       42.118071          59.819724           1.883356
# min    9.000000e+00        1.000000           0.000000           0.000000
# 25%    5.500000e+01        1.000000           1.000000           0.020000
# 50%    8.500000e+01        2.000000           6.000000           0.210000
# 75%    1.480000e+02        4.000000          29.000000           0.900000
# max    1.173721e+06     1125.000000         648.000000          81.060000
#
#        calculated_host_listings_count  availability_365  \
# count                     6977.000000       6977.000000
# mean                         7.251971         65.408772
# std                         25.062374        114.209065
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000          0.000000
# 75%                          3.000000         78.000000
# max                        162.000000        365.000000
#
#        number_of_reviews_ltm  license
# count            6977.000000      0.0
# mean                2.958005      NaN
# std                11.218871      NaN
# min                 0.000000      NaN
# 25%                 0.000000      NaN
# 50%                 0.000000      NaN
# 75%                 1.000000      NaN
# max               366.000000      NaN

# %%
# Recode data as categorical
# https://datascience.stackexchange.com/questions/29093/continuous-variable-to-categorical-by-quartiles
listing_encoded = listing.copy()
listing_encoded['minimum_nights'] = pd.qcut(listing['minimum_nights'], q=2, labels=["minimum_nights_low", "minimum_nights_high"])
listing_encoded['number_of_reviews'] = pd.qcut(listing['number_of_reviews'], q=3, labels=["number_of_reviews_low", "minimum_nights_medium", "number_of_reviews_high"])
listing_encoded['reviews_per_month'] = pd.qcut(listing['reviews_per_month'], q=2, labels=["reviews_per_month_low", "reviews_per_month_high"])
listing_encoded['calculated_host_listings_count'] = pd.cut(listing['calculated_host_listings_count'], 
                                                bins=[0, 2, 327],
                                                labels=["calculated_host_listings_count_low", "calculated_host_listings_count_high"])

#NEEDS TO BE FIXED
#listing_encoded['availability_365'] = pd.qcut(listing['availability_365'], q=2, labels=["availability_low", "availability_high"])

# %%
listing_encoded.isnull().sum()
# Out:
# name                                 1
# host_id                              0
# neighbourhood_group               6977
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           6977
# dtype: int64

# %%
#initializing empty list where we are going to put our name strings
_names_=[]
#getting name strings from the column and appending it to the list
for name in listing.name:
    _names_.append(name)
#setting a function that will split those name strings into separate words   
def split_name(name):
    spl=str(name).split()
    return spl
#initializing empty list where we are going to have words counted
_names_for_count_=[]
#getting name string from our list and using split function, later appending to list above
for x in _names_:
    for word in split_name(x):
        word=word.lower()
        _names_for_count_.append(word)

# %%
#we are going to use counter
from collections import Counter
#let's see top 25 used words by host to name their listing
_top_25_w=Counter(_names_for_count_).most_common()
_top_25_w=_top_25_w[0:25]

# %%
#now let's put our findings in dataframe for further visualizations
sub_w=pd.DataFrame(_top_25_w)
sub_w.rename(columns={0:'Words', 1:'Count'}, inplace=True)

# %%
viz_5=sns.barplot(x='Words', y='Count', data=sub_w)
viz_5.set_title('Counts of the top 25 used words for listing names')
viz_5.set_ylabel('Count of words')
viz_5.set_xlabel('Words')
viz_5.set_xticklabels(viz_5.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'in'),
#  Text(1, 0, 'city'),
#  Text(2, 0, 'room'),
#  Text(3, 0, 'dublin'),
#  Text(4, 0, 'apartment'),
#  Text(5, 0, 'double'),
#  Text(6, 0, 'bedroom'),
#  Text(7, 0, 'centre'),
#  Text(8, 0, 'the'),
#  Text(9, 0, 'to'),
#  Text(10, 0, 'bed'),
#  Text(11, 0, '-'),
#  Text(12, 0, 'home'),
#  Text(13, 0, 'house'),
#  Text(14, 0, 'with'),
#  Text(15, 0, '2'),
#  Text(16, 0, 'private'),
#  Text(17, 0, 'modern'),
#  Text(18, 0, 'cosy'),
#  Text(19, 0, 'of'),
#  Text(20, 0, 'near'),
#  Text(21, 0, 'and'),
#  Text(22, 0, '1'),
#  Text(23, 0, 'spacious'),
#  Text(24, 0, 'close')]

# %%
sns.set_palette("muted")
from pylab import *
f, ax = plt.subplots(figsize=(8, 6))

subplot(2,3,1)
sns.distplot(listing['price'])

subplot(2,3,2)
sns.distplot(listing['minimum_nights'])

subplot(2,3,3)
sns.distplot(listing['number_of_reviews'])

subplot(2,3,4)
sns.distplot(listing['reviews_per_month'])

subplot(2,3,5)
sns.distplot(listing['calculated_host_listings_count'])

subplot(2,3,6)
sns.distplot(listing['availability_365'])

plt.tight_layout() # avoid overlap of plotsplt.draw()

# %%
from pylab import *
f, ax = plt.subplots(figsize=(8, 6))

subplot(2,3,1)
sns.boxplot(y = listing['price']) 

subplot(2,3,2)
sns.boxplot(y = listing['minimum_nights'])

subplot(2,3,3)
sns.boxplot(y = listing['number_of_reviews'])

subplot(2,3,4)
sns.boxplot(y = listing['reviews_per_month'])

subplot(2,3,5)
sns.boxplot(y = listing['calculated_host_listings_count'])

subplot(2,3,6)
sns.boxplot(y = listing['availability_365'])

plt.tight_layout() # avoid overlap of plots
plt.draw()

# %%
# Set up color blind friendly color palette
# The palette with grey:
cbPalette = ["#999999", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
# The palette with black:
cbbPalette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

# sns.palplot(sns.color_palette(cbPalette))
# sns.palplot(sns.color_palette(cbbPalette))

sns.set_palette(cbPalette)
#sns.set_palette(cbbPalette)

# %%
title = 'Properties per Neighbourhood'
sns.countplot(listing['neighbourhood'])
plt.title(title)
plt.ioff()

# %%
title = 'Properties per Room Type'
sns.countplot(listing['room_type'])
plt.title(title)
plt.ioff()

# %%
listing.drop(['neighbourhood_group'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,10))
title = 'Correlation matrix of numerical variables'
sns.heatmap(listing.corr(), square=True)
plt.title(title)
plt.ioff()

# %%
title = 'Neighbourhood Group Location'
plt.figure(figsize=(10,6))
sns.scatterplot(listing.longitude,listing.latitude,hue=listing.neighbourhood).set_title(title)
plt.ioff()

title = 'Room type location per Neighbourhood Group'
plt.figure(figsize=(10,6))
sns.scatterplot(listing.longitude,listing.latitude,hue=listing.room_type).set_title(title)
plt.ioff()

# %%
sub_1=listing.loc[listing['neighbourhood'] == 'Dn Laoghaire-Tathdown']
price_sub1=sub_1[['price']]
#Manhattan
sub_2=listing.loc[listing['neighbourhood'] == 'South Dublin']
price_sub2=sub_2[['price']]
#Queens
sub_3=listing.loc[listing['neighbourhood'] == 'Dublin City']
price_sub3=sub_3[['price']]
#Staten Island
sub_4=listing.loc[listing['neighbourhood'] == 'Fingal']
price_sub4=sub_4[['price']]

#putting all the prices' dfs in the list
price_list_by_n=[price_sub1, price_sub2, price_sub3, price_sub4]

# %%
p_l_b_n_2=[]
#creating list with known values in neighbourhood_group column
nei_list=['Dn Laoghaire-Tathdown', 'South Dublin', 'Dublin City', 'Fingal']
#creating a for loop to get statistics for price ranges and append it to our empty list
for x in price_list_by_n:
    i=x.describe(percentiles=[.25, .50, .75])
    i=i.iloc[3:]
    i.reset_index(inplace=True)
    i.rename(columns={'index':'Stats'}, inplace=True)
    p_l_b_n_2.append(i)
#changing names of the price column to the area name for easier reading of the table    
p_l_b_n_2[0].rename(columns={'price':nei_list[0]}, inplace=True)
p_l_b_n_2[1].rename(columns={'price':nei_list[1]}, inplace=True)
p_l_b_n_2[2].rename(columns={'price':nei_list[2]}, inplace=True)
p_l_b_n_2[3].rename(columns={'price':nei_list[3]}, inplace=True)

#finilizing our dataframe for final view    
stat_df=p_l_b_n_2
stat_df=[df.set_index('Stats') for df in stat_df]
stat_df=stat_df[0].join(stat_df[1:])
stat_df
# Out:
#        Dn Laoghaire-Tathdown  South Dublin  Dublin City  Fingal
# Stats
# min                      NaN          12.0         9.00    15.0
# 25%                      NaN          40.0        56.25    48.0
# 50%                      NaN          55.0        90.00    72.5
# 75%                      NaN          95.0       150.00   120.0
# max                      NaN        2286.0   1173721.00  4000.0

# %%
#creating a sub-dataframe with no extreme values / less than 500
sub_6=listing[listing.price < 500]
#using violinplot to showcase density and distribtuion of prices 
viz_2=sns.violinplot(data=sub_6, x='neighbourhood', y='price')
viz_2.set_title('Density and distribution of prices for each neighberhood')
# Out:
# Text(0.5, 1.0, 'Density and distribution of prices for each neighberhood')

# %%
listing.neighbourhood.value_counts().head(10)
# Out:
# Dublin City              5334
# Dn Laoghaire-Rathdown     742
# Fingal                    616
# South Dublin              285
# Name: neighbourhood, dtype: int64

# %%
#let's what we can do with our given longtitude and latitude columns

#let's see how scatterplot will come out 
viz_4=sub_6.plot(kind='scatter', x='longitude', y='latitude', label='availability_365', c='price',
                  cmap=plt.get_cmap('jet'), colorbar=True, alpha=0.4, figsize=(14,8))
viz_4.legend()

# %%
# Load the Dataset  
#data.drop(['latitude', 'name',], axis=1, inplace=True)
listing.drop(['name'], axis=1, inplace=True)
listing_copy = listing.copy()

# %%
# log10 transform
# https://stackoverflow.com/questions/30794525/adding-one-to-all-the-values-in-a-dataframe
# data_copy = data.copy()
listing.minimum_nights += 0.000000001
listing['minimum_nights'] = np.log10(listing['minimum_nights'])
listing.number_of_reviews += 0.000000001
listing['number_of_reviews'] = np.log10(listing['number_of_reviews'])
listing.reviews_per_month += 0.000000001
listing['reviews_per_month'] = np.log10(listing['reviews_per_month'])
listing.calculated_host_listings_count += 0.000000001
listing['calculated_host_listings_count'] = np.log10(listing['calculated_host_listings_count'])
listing.availability_365 += 0.000000001
listing['availability_365'] = np.log10(listing['availability_365'])

# %%
# Encoding categorical data
listing = pd.get_dummies(listing, columns=['room_type'], drop_first=True)
listing = pd.get_dummies(listing, columns=['neighbourhood'], drop_first=True)
listing = pd.get_dummies(listing, columns=['neighbourhood_group'], drop_first=True)

# %%
# Filter the dataset for prices between 50 and $175
listing_filtered_low = listing.loc[(listing['price'] < 175)]

# %%
# Filter the dataset for prices superior to $175
listing_filtered_high = listing.loc[(listing['price'] > 175)]

# %%
# Split the dataset
X = listing_filtered_low.drop('price', axis=1).values
y = listing_filtered_low['price'].values
y = np.log10(y)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predicting the Test set results
y_pred = lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-1f32c18df00f> in <module>
#       6 from sklearn.linear_model import LinearRegression
#       7 lr = LinearRegression()
# ----> 8 lr.fit(X_train, y_train)
#       9
#      10 # Predicting the Test set results
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Darragh'

# %%
# Compare predicted and actual values
df= pd.DataFrame({'Actual': np.round(10 ** y_test, 0), 
                   'Predicted': np.round(10 ** y_pred, 0)})
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-161-ec1ef53e2ce1> in <module>
#       1 # Compare predicted and actual values
#       2 df= pd.DataFrame({'Actual': np.round(10 ** y_test, 0),
# ----> 3                    'Predicted': np.round(10 ** y_pred, 0)})
#       4 df.head(10)
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.metrics import r2_score

print('Price mean:', np.round(np.mean(y), 2))  
print('Price std:', np.round(np.std(y), 2))
print('RMSE:', np.round(np.sqrt(metrics.mean_squared_error(y_test, lr.predict(X_test))), 2))
print('R2 score train:', np.round(r2_score(y_train, lr.predict(X_train), multioutput='variance_weighted'), 2))
print('R2 score test:', np.round(r2_score(y_test, lr.predict(X_test), multioutput='variance_weighted'), 2))
# Out:
# Price mean: 1.85
# Price std: 0.22
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-162-858f6bd63b7e> in <module>
#       5 print('Price mean:', np.round(np.mean(y), 2))
#       6 print('Price std:', np.round(np.std(y), 2))
# ----> 7 print('RMSE:', np.round(np.sqrt(metrics.mean_squared_error(y_test, lr.predict(X_test))), 2))
#       8 print('R2 score train:', np.round(r2_score(y_train, lr.predict(X_train), multioutput='variance_weighted'), 2))
#       9 print('R2 score test:', np.round(r2_score(y_test, lr.predict(X_test), multioutput='variance_weighted'), 2))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
X = listing_filtered_high.drop('price', axis=1).values
y = listing_filtered_high['price'].values
y = np.log10(y)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

#trying to get rid of the error when not using this line
#ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

#X_test.fillna(X_test.mean())



# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predicting the Test set results
y_pred = lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-010dfd24be13> in <module>
#      13 from sklearn.linear_model import LinearRegression
#      14 lr = LinearRegression()
# ---> 15 lr.fit(X_train, y_train)
#      16
#      17 # Predicting the Test set results
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Darragh'

# %%
df = pd.DataFrame({'Actual': np.round(10 ** y_test, 0), 
                   'Predicted': np.round(10 ** y_pred, 0)})
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-165-7776d46d6021> in <module>
#       1 df = pd.DataFrame({'Actual': np.round(10 ** y_test, 0),
# ----> 2                    'Predicted': np.round(10 ** y_pred, 0)})
#       3 df.head(10)
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.metrics import r2_score

print('Price mean:', np.round(np.mean(y), 2))  
print('Price std:', np.round(np.std(y), 2))
print('RMSE:', np.round(np.sqrt(metrics.mean_squared_error(y_test, lr.predict(X_test))), 2))
print('R2 score train:', np.round(r2_score(y_train, lr.predict(X_train), multioutput='variance_weighted'), 2))
print('R2 score test:', np.round(r2_score(y_test, lr.predict(X_test), multioutput='variance_weighted'), 2))
# Out:
# Price mean: 2.49
# Price std: 0.27
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-166-858f6bd63b7e> in <module>
#       5 print('Price mean:', np.round(np.mean(y), 2))
#       6 print('Price std:', np.round(np.std(y), 2))
# ----> 7 print('RMSE:', np.round(np.sqrt(metrics.mean_squared_error(y_test, lr.predict(X_test))), 2))
#       8 print('R2 score train:', np.round(r2_score(y_train, lr.predict(X_train), multioutput='variance_weighted'), 2))
#       9 print('R2 score test:', np.round(r2_score(y_test, lr.predict(X_test), multioutput='variance_weighted'), 2))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
#Random Forest Regression

# %%
#https://jakevdp.github.io/PythonDataScienceHandbook/03.07-merge-and-join.html
#http://insideairbnb.com/ireland/
#https://public.opendatasoft.com/explore/dataset/airbnb-listings/export/?disjunctive.host_verifications&disjunctive.amenities&disjunctive.features&q=ireland
#https://app.airbtics.com/airbnb-data/ireland/0/dublin
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html
#https://www.codegrepper.com/code-examples/python/convert+object+to+float64+pandas
#

# %% [markdown]
# # Calendar dataset

# %%
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0      990212  2021-12-09         f  165.00         165.00            10.0
# 1       44077  2021-12-09         f   65.00          65.00             3.0
# 2       44077  2021-12-10         f   65.00          65.00             3.0
# 3       44077  2021-12-11         f   65.00          65.00             3.0
# 4       44077  2021-12-12         f   65.00          65.00             3.0
#
#    maximum_nights
# 0            28.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
calendar.shape
# Out:
# (2546600, 7)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2546600 entries, 0 to 2546599
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 136.0+ MB

# %%
calendar.dtypes
# Out:
# listing_id          int64
# date               object
# available          object
# price              object
# adjusted_price     object
# minimum_nights    float64
# maximum_nights    float64
# dtype: object

# %%
calendar['date'] = pd.to_datetime(calendar.date)
calendar.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2546600 entries, 0 to 2546599
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      2546600 non-null  int64
#  1   date            2546600 non-null  datetime64[ns]
#  2   available       2546600 non-null  object
#  3   price           2546600 non-null  object
#  4   adjusted_price  2546600 non-null  object
#  5   minimum_nights  2546600 non-null  float64
#  6   maximum_nights  2546600 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 136.0+ MB

# %%
#function to clean and convert str columns to numeric

def str_to_num(df,column):
    df[column] = pd.to_numeric(df[column].apply(lambda x : str(x).replace('$','').replace(",",'')),errors='coerce')
    return df

# %%
columns=['price', 'adjusted_price']
for col in columns:
    calendar=str_to_num(calendar,col)
calendar[columns][:2]
# Out:
#    price  adjusted_price
# 0  165.0           165.0
# 1   65.0            65.0

# %%
calendar= str_to_num(calendar,'price')
calendar.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2546600 entries, 0 to 2546599
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      2546600 non-null  int64
#  1   date            2546600 non-null  datetime64[ns]
#  2   available       2546600 non-null  object
#  3   price           2546600 non-null  float64
#  4   adjusted_price  2546600 non-null  float64
#  5   minimum_nights  2546600 non-null  float64
#  6   maximum_nights  2546600 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 136.0+ MB

# %%
calendar.describe()
# Out:
#          listing_id         price  adjusted_price  minimum_nights  \
# count  2.546600e+06  2.546600e+06    2.546600e+06    2.546600e+06
# mean   2.659654e+07  3.091220e+02    3.089447e+02    1.350082e+01
# std    1.426810e+07  1.405084e+04    1.405082e+04    5.441853e+01
# min    4.407700e+04  0.000000e+00    0.000000e+00    0.000000e+00
# 25%    1.529708e+07  5.500000e+01    5.500000e+01    1.000000e+00
# 50%    2.450335e+07  8.500000e+01    8.500000e+01    2.000000e+00
# 75%    3.711744e+07  1.500000e+02    1.500000e+02    4.000000e+00
# max    5.372030e+07  1.173721e+06    1.173721e+06    1.125000e+03
#
#        maximum_nights
# count    2.546600e+06
# mean     6.853560e+02
# std      5.207744e+02
# min      0.000000e+00
# 25%      2.900000e+01
# 50%      1.125000e+03
# 75%      1.125000e+03
# max      1.125000e+03

# %% [markdown]
# # Cleaning data

# %%
calendar.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar.fillna({'price':0}, inplace=True)

# %%
calendar.fillna({'minimum_nights':0}, inplace=True)

# %%
calendar.fillna({'maximum_nights':0}, inplace=True)

# %%
calendar.fillna({'adjusted_price':0}, inplace=True)

# %%
calendar.isnull().sum()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar[calendar.duplicated()]
# Out:
# Empty DataFrame
# Columns: [listing_id, date, available, price, adjusted_price, minimum_nights, maximum_nights]
# Index: []

# %%
calendar.isnull().sum()[calendar.isnull().sum().to_numpy().nonzero()[0]].index
# Out:
# Index([], dtype='object')

# %%
calendar.head()
# Out:
#    listing_id       date available  price  adjusted_price  minimum_nights  \
# 0      990212 2021-12-09         f  165.0           165.0            10.0
# 1       44077 2021-12-09         f   65.0            65.0             3.0
# 2       44077 2021-12-10         f   65.0            65.0             3.0
# 3       44077 2021-12-11         f   65.0            65.0             3.0
# 4       44077 2021-12-12         f   65.0            65.0             3.0
#
#    maximum_nights
# 0            28.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %% [markdown]
# # cols = ['price', 'adjusted_price']

# %% [markdown]
# # calendar[cols] = calendar[cols].replace({'\$': '', ',': ''}, regex=True) #removing extra chracters from dataset like $ etc

# %%
calendar.head()
# Out:
#    listing_id       date available  price  adjusted_price  minimum_nights  \
# 0      990212 2021-12-09         f  165.0           165.0            10.0
# 1       44077 2021-12-09         f   65.0            65.0             3.0
# 2       44077 2021-12-10         f   65.0            65.0             3.0
# 3       44077 2021-12-11         f   65.0            65.0             3.0
# 4       44077 2021-12-12         f   65.0            65.0             3.0
#
#    maximum_nights
# 0            28.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
features = calendar.columns[:-1].tolist()
print(calendar.shape)
# Out:
# (2546600, 7)

# %%
sns.set(style="whitegrid", font_scale=1.2)
plt.subplots(figsize = (8,8))
sns.countplot('available',data=calendar).set_title('Available for f and t')
# Out:
# Text(0.5, 1.0, 'Available for f and t')

# %%
plt.figure(figsize=(20,10))
title = 'Correlation matrix of numerical variables'
sns.heatmap(calendar.corr(), square=True, cmap='coolwarm')
plt.title(title)
plt.ioff()

# %%
title = 'Availabilty for t and f'
plt.figure(figsize=(10,6))
sns.scatterplot(calendar.maximum_nights,calendar.minimum_nights,hue=calendar.available).set_title(title)
plt.ioff()

# %%
(calendar.groupby('minimum_nights')['price'].mean().sort_values(ascending=False)[:20]).plot(kind="bar", figsize=(16,8));
plt.title("Average Listing price");
plt.xlabel('Average Price $');
plt.ylabel('minimum nights');
plt.xticks(rotation=60);

# %%
(calendar.groupby('maximum_nights')['price'].mean().sort_values(ascending=False)[:50]).plot(kind="bar", figsize=(16,8));
plt.title("Average Listing price");
plt.xlabel('Average Price $');
plt.ylabel('Maximum nights');
plt.xticks(rotation=50);

# %% [markdown]
# # Dataset airbnb_listing EDA

# %%
airbnb_listing.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0   3493152   https://www.airbnb.com/rooms/3493152  20170304065726
# 1     41445     https://www.airbnb.com/rooms/41445  20170304065726
# 2    686205    https://www.airbnb.com/rooms/686205  20170304065726
# 3  13108139  https://www.airbnb.com/rooms/13108139  20170304065726
# 4   3621702   https://www.airbnb.com/rooms/3621702  20170304065726
#
#   Last Scraped                                               Name  \
# 0   2017-03-05  Private double bed on hill top nr trains and s...
# 1   2017-03-04  2 Double bed apartment in quiet area North London
# 2   2017-03-05  Secret Charlton Greenwich Borough Mews CoachHouse
# 3   2017-03-04                   Beautiful room in central London
# 4   2017-03-05                 2 mins Baker St tube & Regent's Pk
#
#                                              Summary  \
# 0  We have a spare double bedroom in our flat in ...
# 1  The apartment is on the ground floor (no stair...
# 2  An 1820s Mews with a contemporary interior & t...
# 3  The apartment is in a lovely tree lined street...
# 4  The room is on the 2nd floor of a beautiful Ge...
#
#                                                Space  \
# 0  The bedroom is very private (our room is locat...
# 1  Stylish apartment with a lot of character furn...
# 2  Are you ready to Step back in time, to when hi...
# 3  This is a private bedroom within an apartment....
# 4  The room contains a king-size bed, a large war...
#
#                                          Description Experiences Offered  \
# 0  We have a spare double bedroom in our flat in ...                none
# 1  The apartment is on the ground floor (no stair...                none
# 2  An 1820s Mews with a contemporary interior & t...            business
# 3  The apartment is in a lovely tree lined street...                none
# 4  The room is on the 2nd floor of a beautiful Ge...                none
#
#                                Neighborhood Overview  ...  \
# 0  Crystal Palace is a scenic suburb of London wi...  ...
# 1                   Quite area popular with families  ...
# 2  Historical, easy to access the city, lots of o...  ...
# 3  This is a perfect room for easy travelling. Th...  ...
# 4  We've lived here for 22 years and love the con...  ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                   10.0                10.0
# 1                         9.0                    9.0                 8.0
# 2                        10.0                    9.0                10.0
# 3                        10.0                   10.0                10.0
# 4                        10.0                   10.0                10.0
#
#   License Jurisdiction Names Cancellation Policy  \
# 0     NaN                NaN            moderate
# 1     NaN                NaN              strict
# 2     NaN                NaN            flexible
# 3     NaN                NaN            moderate
# 4     NaN                NaN            flexible
#
#   Calculated host listings count Reviews per Month  \
# 0                            1.0              0.69
# 1                            1.0              0.20
# 2                            1.0              0.18
# 3                            3.0              5.49
# 4                            2.0              1.10
#
#                                Geolocation  \
# 0    51.42118451930785,-0.0799542878255594
# 1   51.61648002441267,-0.25787617664571394
# 2     51.4853801203812,0.03237223028393566
# 3  51.489535144910604,-0.19548113484788876
# 4   51.52342720623529,-0.15851680515925295
#
#                                             Features
# 0        Host Has Profile Pic,Host Identity Verified
# 1        Host Has Profile Pic,Host Identity Verified
# 2  Host Has Profile Pic,Host Identity Verified,Is...
# 3        Host Has Profile Pic,Host Identity Verified
# 4  Host Is Superhost,Host Has Profile Pic,Host Id...
#
# [5 rows x 89 columns]

# %%
airbnb_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8151 entries, 0 to 8150
# Data columns (total 89 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              8151 non-null   int64
#  1   Listing Url                     8151 non-null   object
#  2   Scrape ID                       8151 non-null   int64
#  3   Last Scraped                    8151 non-null   object
#  4   Name                            8149 non-null   object
#  5   Summary                         8019 non-null   object
#  6   Space                           5396 non-null   object
#  7   Description                     8150 non-null   object
#  8   Experiences Offered             8151 non-null   object
#  9   Neighborhood Overview           4794 non-null   object
#  10  Notes                           3389 non-null   object
#  11  Transit                         5015 non-null   object
#  12  Access                          4929 non-null   object
#  13  Interaction                     4699 non-null   object
#  14  House Rules                     5149 non-null   object
#  15  Thumbnail Url                   7407 non-null   object
#  16  Medium Url                      7407 non-null   object
#  17  Picture Url                     8137 non-null   object
#  18  XL Picture Url                  7407 non-null   object
#  19  Host ID                         8151 non-null   int64
#  20  Host URL                        8151 non-null   object
#  21  Host Name                       8151 non-null   object
#  22  Host Since                      8151 non-null   object
#  23  Host Location                   8115 non-null   object
#  24  Host About                      5105 non-null   object
#  25  Host Response Time              6560 non-null   object
#  26  Host Response Rate              6560 non-null   float64
#  27  Host Acceptance Rate            174 non-null    object
#  28  Host Thumbnail Url              8151 non-null   object
#  29  Host Picture Url                8151 non-null   object
#  30  Host Neighbourhood              5398 non-null   object
#  31  Host Listings Count             8151 non-null   int64
#  32  Host Total Listings Count       8151 non-null   int64
#  33  Host Verifications              8147 non-null   object
#  34  Street                          8151 non-null   object
#  35  Neighbourhood                   4807 non-null   object
#  36  Neighbourhood Cleansed          8151 non-null   object
#  37  Neighbourhood Group Cleansed    233 non-null    object
#  38  City                            8137 non-null   object
#  39  State                           7819 non-null   object
#  40  Zipcode                         3901 non-null   object
#  41  Market                          8126 non-null   object
#  42  Smart Location                  8151 non-null   object
#  43  Country Code                    8151 non-null   object
#  44  Country                         8151 non-null   object
#  45  Latitude                        8151 non-null   float64
#  46  Longitude                       8151 non-null   float64
#  47  Property Type                   8151 non-null   object
#  48  Room Type                       8151 non-null   object
#  49  Accommodates                    8151 non-null   int64
#  50  Bathrooms                       8133 non-null   float64
#  51  Bedrooms                        8147 non-null   float64
#  52  Beds                            8125 non-null   float64
#  53  Bed Type                        8151 non-null   object
#  54  Amenities                       8079 non-null   object
#  55  Square Feet                     116 non-null    float64
#  56  Price                           8137 non-null   float64
#  57  Weekly Price                    1502 non-null   float64
#  58  Monthly Price                   1270 non-null   float64
#  59  Security Deposit                2837 non-null   float64
#  60  Cleaning Fee                    4864 non-null   float64
#  61  Guests Included                 8151 non-null   int64
#  62  Extra People                    8151 non-null   int64
#  63  Minimum Nights                  8151 non-null   int64
#  64  Maximum Nights                  8151 non-null   int64
#  65  Calendar Updated                8151 non-null   object
#  66  Has Availability                33 non-null     object
#  67  Availability 30                 8151 non-null   int64
#  68  Availability 60                 8151 non-null   int64
#  69  Availability 90                 8151 non-null   int64
#  70  Availability 365                8151 non-null   int64
#  71  Calendar last Scraped           8151 non-null   object
#  72  Number of Reviews               8151 non-null   int64
#  73  First Review                    6495 non-null   object
#  74  Last Review                     6499 non-null   object
#  75  Review Scores Rating            6408 non-null   float64
#  76  Review Scores Accuracy          6391 non-null   float64
#  77  Review Scores Cleanliness       6394 non-null   float64
#  78  Review Scores Checkin           6383 non-null   float64
#  79  Review Scores Communication     6398 non-null   float64
#  80  Review Scores Location          6388 non-null   float64
#  81  Review Scores Value             6387 non-null   float64
#  82  License                         66 non-null     object
#  83  Jurisdiction Names              347 non-null    object
#  84  Cancellation Policy             8151 non-null   object
#  85  Calculated host listings count  8150 non-null   float64
#  86  Reviews per Month               6495 non-null   float64
#  87  Geolocation                     8151 non-null   object
#  88  Features                        8141 non-null   object
# dtypes: float64(21), int64(15), object(53)
# memory usage: 5.5+ MB

# %%
airbnb_listing.isnull().sum()
# Out:
# ID                                   0
# Listing Url                          0
# Scrape ID                            0
# Last Scraped                         0
# Name                                 2
#                                   ...
# Cancellation Policy                  0
# Calculated host listings count       1
# Reviews per Month                 1656
# Geolocation                          0
# Features                            10
# Length: 89, dtype: int64
